# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='tip', y='total_bill', data=tips)

# %% [markdown]
# ## grouping

# %%
sns.relplot(x='tip', y='total_bill', data=tips, hue='smoker') # huee is the colour sepration terms in seaborn in relational plot

# %%
sns.relplot(x='tip', y='total_bill', data=tips, hue='day')

# %%
sns.relplot(x='tip', y='total_bill', data=tips, hue='day', style='smoker') # this is group in group, # style bill give the grouping by its own idivisual style of represantaion

# %%
sns.relplot(x='tip', y='total_bill', data=tips, hue='day', style='smoker', size='size') # size is also gives on grouping

# %%
sns.relplot(x='tip', y='total_bill', data=tips, size='tip')# differentiate on the basis of the tips

# %%
df=pd.DataFrame(np.random.rand(300,2), columns=['a','b'])

# %%
sns.relplot(x='a', y='b',kind='line', data=df )

# %%
sns.relplot(x='a', y='b',kind='line', data=df , sort=True) # shorting the element

# %%
iris=sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x='sepal_length',y='sepal_width', data= iris)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# we have to plot the graph between the day and bill , Means to draw the plot between catogorical data and numerical data

# %%
sns.catplot(x='day', y='tip', data=tips)

# %%
sns.catplot(x='smoker', y='tip', data=tips)

# %%
sns.catplot(x='day', y='tip', kind='box', data=tips) # box plot is more clear than plotly than sns

# %%
sns.catplot(x='day', y='tip', kind='box', data=tips, hue='sex') # gruoping

# %%
x=np.random.randn(1000)

# %%
x
# Out:
# array([-2.51517147e+00,  1.34828072e+00, -6.84432580e-02, -1.33645857e+00,
#         9.50926153e-01,  4.24985825e-01,  3.10037325e-01, -9.86910907e-01,
#         6.71125231e-02,  5.43516484e-01, -1.35908160e+00,  3.36402810e-01,
#         7.47230611e-01,  1.59439576e+00,  1.54393810e+00, -3.90107132e-01,
#        -9.95712392e-01, -1.43858028e-01,  6.29152647e-01, -7.18617310e-01,
#        -4.98936921e-01,  3.64111872e-01,  1.41770926e-01, -1.31909198e+00,
#         8.69568674e-01, -9.76622054e-01,  3.07012148e-01,  1.14951530e+00,
#         2.16587656e-01, -3.82585451e-01, -2.33705894e-01,  1.42346522e+00,
#         2.35052892e-01, -1.15175908e+00,  9.08277437e-02, -1.96250469e+00,
#         1.29024317e-01,  1.39996981e+00, -7.41779567e-01,  1.51015988e-01,
#        -2.66025235e-01, -1.76055061e+00, -1.52032341e-01, -1.33004265e-01,
#        -3.84935951e-01, -7.51245352e-02, -6.87843133e-01,  3.58102561e-01,
# ...

# %%
sns.distplot(x) # plot the stand distribution
# Out:
# c:\users\itnes\appdata\local\programs\python\python36\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
x=np.random.randn(1000000)
sns.distplot(x)
# Out:
# c:\users\itnes\appdata\local\programs\python\python36\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
# when the data goes huge it give us complete the distribution rather than less data
# by this distplot check the normal distributted graph of the any data

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# joint plot

# %%
sns.jointplot(x= tips['total_bill'], y = tips['tip']) # relation between distribution of the total_bill and tip and histogram of the tatal_bil and tip

# %%
x=np.random.randn(10000)

# %%
x
# Out:
# array([-0.47013663,  1.92441276, -0.04847538, ...,  0.51797342,
#        -0.17871337,  0.40555686])

# %%
x=np.random.rand(10000)

# %%
x
# Out:
# array([0.18389387, 0.85892007, 0.76680043, ..., 0.18470923, 0.38240212,
#        0.59260521])

# %%
sns.distplot(x)
# Out:
# c:\users\itnes\appdata\local\programs\python\python36\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
# you can get the normal tendency from the histogram

# %%
sns.jointplot(x= tips['total_bill'], y = tips['tip'], kind='hex')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris)# it

# %%
sns.lmplot(x='total_bill', y='tip', data=tips) # real plot create the graph

# %%
sns.regplot(x='total_bill', y='tip', data=tips) # regretion plot
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, col='day') # draw the line between day
