# %%
import pandas as pd

# %%
data=pd.read_csv('Amazon Web Services.csv')

# %%
data
# Out:
#                     user_name#repo_name#star#repo_url
# 0   serverless#serverless#39700#https://github.com...
# 1   localstack#localstack#30300#https://github.com...
# 2   donnemartin#data-science-ipython-notebooks#211...
# 3   ramitsurana#awesome-kubernetes#11600#https://g...
# 4   aws#aws-cli#11000#https://github.com//aws/aws-cli
# 5   kubernetes-sigs#kubespray#10600#https://github...
# 6   donnemartin#awesome-aws#9300#https://github.co...
# 7      apereo#cas#8600#https://github.com//apereo/cas
# 8   pulumi#pulumi#8600#https://github.com//pulumi/...
# 9   bregman-arie#devops-exercises#8400#https://git...
# 10           apex#up#8200#https://github.com//apex/up
# 11  aws-amplify#amplify-js#8100#https://github.com...
# 12   aws#chalice#7900#https://github.com//aws/chalice
# 13  aws#serverless-application-model#7900#https://...
# 14  google#go-cloud#7700#https://github.com//googl...
# 15  mozilla#sops#7500#https://github.com//mozilla/...
# ...

# %%
data.head()
# Out:
#                    user_name#repo_name#star#repo_url
# 0  serverless#serverless#39700#https://github.com...
# 1  localstack#localstack#30300#https://github.com...
# 2  donnemartin#data-science-ipython-notebooks#211...
# 3  ramitsurana#awesome-kubernetes#11600#https://g...
# 4  aws#aws-cli#11000#https://github.com//aws/aws-cli

# %%
data.head(20)
# Out:
#                     user_name#repo_name#star#repo_url
# 0   serverless#serverless#39700#https://github.com...
# 1   localstack#localstack#30300#https://github.com...
# 2   donnemartin#data-science-ipython-notebooks#211...
# 3   ramitsurana#awesome-kubernetes#11600#https://g...
# 4   aws#aws-cli#11000#https://github.com//aws/aws-cli
# 5   kubernetes-sigs#kubespray#10600#https://github...
# 6   donnemartin#awesome-aws#9300#https://github.co...
# 7      apereo#cas#8600#https://github.com//apereo/cas
# 8   pulumi#pulumi#8600#https://github.com//pulumi/...
# 9   bregman-arie#devops-exercises#8400#https://git...
# 10           apex#up#8200#https://github.com//apex/up
# 11  aws-amplify#amplify-js#8100#https://github.com...
# 12   aws#chalice#7900#https://github.com//aws/chalice
# 13  aws#serverless-application-model#7900#https://...
# 14  google#go-cloud#7700#https://github.com//googl...
# 15  mozilla#sops#7500#https://github.com//mozilla/...
# ...

# %%
data.tail()
# Out:
#                     user_name#repo_name#star#repo_url
# 25  aws#amazon-sagemaker-examples#5500#https://git...
# 26  donnemartin#dev-setup#5400#https://github.com/...
# 27  gruntwork-io#terratest#5200#https://github.com...
# 28  gruntwork-io#terragrunt#5000#https://github.co...
# 29  99designs#aws-vault#4900#https://github.com//9...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
df= data.head()

# %%
df.to_csv('my_csv.csv')

# %%
pwd()
# Out:
# 'D:\\Data_science_class\\pandas'

# %%
# !dir
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is 1EDA-CC31
#
#  Directory of D:\Data_science_class\pandas
#
# 10-06-2021  06:44    <DIR>          .
# 10-06-2021  06:44    <DIR>          ..
# 06-06-2021  16:08    <DIR>          .ipynb_checkpoints
# 06-06-2021  10:18             2,067 Amazon Web Services.csv
# 06-06-2021  15:42        43,890,380 cricket_data.csv
# 10-06-2021  06:51               441 my_csv.csv
# 06-06-2021  15:23             3,076 my_picle
# 10-06-2021  06:44           205,444 pandas.ipynb
# 06-06-2021  16:00            32,627 Player.csv
# 10-06-2021  06:50             7,116 result.csv
#                7 File(s)     44,141,151 bytes
#                3 Dir(s)  57,835,048,960 bytes free

# %%
pd.read_csv('my_csv.csv')
# Out:
#    Unnamed: 0                  user_name#repo_name#star#repo_url
# 0           0  serverless#serverless#39700#https://github.com...
# 1           1  localstack#localstack#30300#https://github.com...
# 2           2  donnemartin#data-science-ipython-notebooks#211...
# 3           3  ramitsurana#awesome-kubernetes#11600#https://g...
# 4           4  aws#aws-cli#11000#https://github.com//aws/aws-cli

# %%
pd.read_csv('Amazon Web Services.csv')
# Out:
#                     user_name#repo_name#star#repo_url
# 0   serverless#serverless#39700#https://github.com...
# 1   localstack#localstack#30300#https://github.com...
# 2   donnemartin#data-science-ipython-notebooks#211...
# 3   ramitsurana#awesome-kubernetes#11600#https://g...
# 4   aws#aws-cli#11000#https://github.com//aws/aws-cli
# 5   kubernetes-sigs#kubespray#10600#https://github...
# 6   donnemartin#awesome-aws#9300#https://github.co...
# 7      apereo#cas#8600#https://github.com//apereo/cas
# 8   pulumi#pulumi#8600#https://github.com//pulumi/...
# 9   bregman-arie#devops-exercises#8400#https://git...
# 10           apex#up#8200#https://github.com//apex/up
# 11  aws-amplify#amplify-js#8100#https://github.com...
# 12   aws#chalice#7900#https://github.com//aws/chalice
# 13  aws#serverless-application-model#7900#https://...
# 14  google#go-cloud#7700#https://github.com//googl...
# 15  mozilla#sops#7500#https://github.com//mozilla/...
# ...

# %%
pd.read_csv('Amazon Web Services.csv', sep='#')
# Out:
#           user_name                       repo_name   star  \
# 0        serverless                      serverless  39700
# 1        localstack                      localstack  30300
# 2       donnemartin  data-science-ipython-notebooks  21100
# 3       ramitsurana              awesome-kubernetes  11600
# 4               aws                         aws-cli  11000
# 5   kubernetes-sigs                       kubespray  10600
# 6       donnemartin                     awesome-aws   9300
# 7            apereo                             cas   8600
# 8            pulumi                          pulumi   8600
# 9      bregman-arie                devops-exercises   8400
# 10             apex                              up   8200
# 11      aws-amplify                      amplify-js   8100
# 12              aws                         chalice   7900
# 13              aws    serverless-application-model   7900
# 14           google                        go-cloud   7700
# ...

# %%
pd.read_csv('Amazon Web Services.csv', sep='#', header=None)
# Out:
#                   0                               1      2  \
# 0         user_name                       repo_name   star
# 1        serverless                      serverless  39700
# 2        localstack                      localstack  30300
# 3       donnemartin  data-science-ipython-notebooks  21100
# 4       ramitsurana              awesome-kubernetes  11600
# 5               aws                         aws-cli  11000
# 6   kubernetes-sigs                       kubespray  10600
# 7       donnemartin                     awesome-aws   9300
# 8            apereo                             cas   8600
# 9            pulumi                          pulumi   8600
# 10     bregman-arie                devops-exercises   8400
# 11             apex                              up   8200
# 12      aws-amplify                      amplify-js   8100
# 13              aws                         chalice   7900
# 14              aws    serverless-application-model   7900
# ...

# %%
#change the name of collumn 
pd.read_csv('Amazon Web Services.csv', sep='#', header=None, names=['a','b','c','d','e'])
# Out:
#                   a                               b      c  \
# 0         user_name                       repo_name   star
# 1        serverless                      serverless  39700
# 2        localstack                      localstack  30300
# 3       donnemartin  data-science-ipython-notebooks  21100
# 4       ramitsurana              awesome-kubernetes  11600
# 5               aws                         aws-cli  11000
# 6   kubernetes-sigs                       kubespray  10600
# 7       donnemartin                     awesome-aws   9300
# 8            apereo                             cas   8600
# 9            pulumi                          pulumi   8600
# 10     bregman-arie                devops-exercises   8400
# 11             apex                              up   8200
# 12      aws-amplify                      amplify-js   8100
# 13              aws                         chalice   7900
# 14              aws    serverless-application-model   7900
# ...

# %%
pd.read_csv('Amazon Web Services.csv', sep='#', header=None, names=['a','b','c','d','e'], skiprows=[0,4,6])
# Out:
#                a                               b      c  \
# 0     serverless                      serverless  39700
# 1     localstack                      localstack  30300
# 2    donnemartin  data-science-ipython-notebooks  21100
# 3            aws                         aws-cli  11000
# 4    donnemartin                     awesome-aws   9300
# 5         apereo                             cas   8600
# 6         pulumi                          pulumi   8600
# 7   bregman-arie                devops-exercises   8400
# 8           apex                              up   8200
# 9    aws-amplify                      amplify-js   8100
# 10           aws                         chalice   7900
# 11           aws    serverless-application-model   7900
# 12        google                        go-cloud   7700
# 13       mozilla                            sops   7500
# 14      caprover                        caprover   7100
# 15           aws                      aws-sdk-go   6900
# ...

# %%
import pandas as pd

# %%
pd.read_csv('Player.csv', na_values=[1])
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0          NaN       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1          2.0      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2          3.0       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3          4.0        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4          5.0  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518      519.0      Subroto Das        NaN          NaN                 NaN
# 519      520.0     K Srinivasan        NaN          NaN                 NaN
# 520      521.0        VK Sharma        NaN          NaN                 NaN
# 521      523.0      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522      524.0      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
pd.read_csv('Player.csv', na_values=['SC Ganguly'])
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1              NaN   8-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
pd.read_csv('Player.csv', na_values=['SC Ganguly', 'BB McCullum'])
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1              NaN   8-Jul-72    Left_Hand    Right-arm medium
# 1            2              NaN  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
pd.read_csv('Amazon Web Services.csv', sep='#', na_values=['serverless'])
# Out:
#           user_name                       repo_name   star  \
# 0               NaN                             NaN  39700
# 1        localstack                      localstack  30300
# 2       donnemartin  data-science-ipython-notebooks  21100
# 3       ramitsurana              awesome-kubernetes  11600
# 4               aws                         aws-cli  11000
# 5   kubernetes-sigs                       kubespray  10600
# 6       donnemartin                     awesome-aws   9300
# 7            apereo                             cas   8600
# 8            pulumi                          pulumi   8600
# 9      bregman-arie                devops-exercises   8400
# 10             apex                              up   8200
# 11      aws-amplify                      amplify-js   8100
# 12              aws                         chalice   7900
# 13              aws    serverless-application-model   7900
# 14           google                        go-cloud   7700
# ...

# %%
pd.read_csv('Player.csv', skiprows=[0,1,4])
# Out:
#        2      BB McCullum  27-Sep-81  Right_Hand    Right-arm medium  \
# 0      3       RT Ponting  19-Dec-74  Right_Hand    Right-arm medium
# 1      5  Mohammad Hafeez  17-Oct-80  Right_Hand  Right-arm offbreak
# 2      6         R Dravid  11-Jan-73  Right_Hand  Right-arm offbreak
# 3      7         W Jaffer  16-Feb-78  Right_Hand  Right-arm offbreak
# 4      8          V Kohli   5-Nov-88  Right_Hand    Right-arm medium
# ..   ...              ...        ...         ...                 ...
# 515  519      Subroto Das        NaN         NaN                 NaN
# 516  520     K Srinivasan        NaN         NaN                 NaN
# 517  521        VK Sharma        NaN         NaN                 NaN
# 518  523      AV Wankhade  14-Mar-92  Right_Hand                 NaN
# 519  524      B Aparajith   8-Jul-94  Right_Hand  Right-arm offbreak
#
#     New Zealand  0  Unnamed: 7
# 0     Australia  0         NaN
# 1      Pakistan  0         NaN
# 2         India  0         NaN
# ...

# %%
data.describe()
# Out:
#                         user_name#repo_name#star#repo_url
# count                                                  30
# unique                                                 30
# top     aws#aws-sam-cli#5500#https://github.com//aws/a...
# freq                                                    1

# %%
data.dtypes
# Out:
# user_name#repo_name#star#repo_url    object
# dtype: object

# %%
df=pd.read_csv('Player.csv')

# %%
df.dtypes
# Out:
# Player_Id          int64
# Player_Name       object
# DOB               object
# Batting_Hand      object
# Bowling_Skill     object
# Country           object
# Is_Umpire          int64
# Unnamed: 7       float64
# dtype: object

# %%
#by defualt description gives the only numerical data description
df.describe()
# Out:
#         Player_Id   Is_Umpire  Unnamed: 7
# count  523.000000  523.000000   12.000000
# mean   262.003824    0.099426    6.500000
# std    151.127981    0.299520    3.605551
# min      1.000000    0.000000    1.000000
# 25%    131.500000    0.000000    3.750000
# 50%    262.000000    0.000000    6.500000
# 75%    392.500000    0.000000    9.250000
# max    524.000000    1.000000   12.000000

# %%
df.head()
# Out:
#    Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0          1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1          2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2          3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3          4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4          5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
#
#        Country  Is_Umpire  Unnamed: 7
# 0        India          0         NaN
# 1  New Zealand          0         NaN
# 2    Australia          0         NaN
# 3    Australia          0         NaN
# 4     Pakistan          0         NaN

# %%
df.to_csv('result.csv', index=False, header=False, columns=['Player_Id', 'DOB'])

# %%
df.tail()
# Out:
#      Player_Id   Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 518        519   Subroto Das        NaN          NaN                 NaN
# 519        520  K Srinivasan        NaN          NaN                 NaN
# 520        521     VK Sharma        NaN          NaN                 NaN
# 521        523   AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524   B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#     Country  Is_Umpire  Unnamed: 7
# 518   India          1         NaN
# 519   India          1         NaN
# 520   India          1         NaN
# 521   India          0         NaN
# 522   India          0         NaN

# %%
df.columns
# Out:
# Index(['Player_Id', 'Player_Name', 'DOB', 'Batting_Hand', 'Bowling_Skill',
#        'Country', 'Is_Umpire', 'Unnamed: 7'],
#       dtype='object')

# %%
df['Player_Id']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 518    519
# 519    520
# 520    521
# 521    523
# 522    524
# Name: Player_Id, Length: 523, dtype: int64

# %%
type(df['Player_Id'])
#if you have only column to access then that type data is called series data
# Out:
# pandas.core.series.Series

# %%
type(df[['Player_Id']])
# you will put the data in double square brcaket , You will get the data frame data
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Player_Id']]
# Out:
#      Player_Id
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ..         ...
# 518        519
# 519        520
# 520        521
# 521        523
# 522        524
#
# [523 rows x 1 columns]

# %%
# but if you want to fetch more than one column it will give the error message
df['Player_Id','Player_Name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Player_Id', 'Player_Name')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-b58a549626e9> in <module>
# ...

# %%
# but these all column, you will provide in the list then , there is no any error
df[['Player_Id','Player_Name']]
# Out:
#      Player_Id      Player_Name
# 0            1       SC Ganguly
# 1            2      BB McCullum
# 2            3       RT Ponting
# 3            4        DJ Hussey
# 4            5  Mohammad Hafeez
# ..         ...              ...
# 518        519      Subroto Das
# 519        520     K Srinivasan
# 520        521        VK Sharma
# 521        523      AV Wankhade
# 522        524      B Aparajith
#
# [523 rows x 2 columns]

# %%
# order doesn't matters 
df[['Country','Player_Id','Player_Name']]
# Out:
#          Country  Player_Id      Player_Name
# 0          India          1       SC Ganguly
# 1    New Zealand          2      BB McCullum
# 2      Australia          3       RT Ponting
# 3      Australia          4        DJ Hussey
# 4       Pakistan          5  Mohammad Hafeez
# ..           ...        ...              ...
# 518        India        519      Subroto Das
# 519        India        520     K Srinivasan
# 520        India        521        VK Sharma
# 521        India        523      AV Wankhade
# 522        India        524      B Aparajith
#
# [523 rows x 3 columns]

# %%
pd.read_excel(r'C:\Users\itnes\Downloads\sample-excel-master\LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx')
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0          NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN
# ...

# %%
# !pip install xlrd

# %%
# if you want to all access in data science package then go for always anaconda powershell direct cmd some time didn't support, It will say to install some extra package
pd.read_excel("C:/Users/itnes/Downloads/sample-excel-master/LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xls", sheet_name="Create your instrument universe")
# Out:
#     Unnamed: 0  Unnamed: 1 Unnamed: 2  Unnamed: 3    Unnamed: 4 Unnamed: 5  \
# 0          NaN         NaN        NaN         NaN           NaN        NaN
# 1          NaN         NaN        NaN         NaN           NaN        NaN
# 2          NaN         NaN        NaN         NaN           NaN        NaN
# 3          NaN         NaN        NaN         NaN           NaN        NaN
# 4          NaN         NaN        NaN         NaN           NaN        NaN
# ..         ...         ...        ...         ...           ...        ...
# 66         NaN         NaN        NaN         NaN  BBG0000D14P3        NaN
# 67         NaN         NaN        NaN         NaN  BBG00FN3B5K8        NaN
# 68         NaN         NaN        NaN         NaN  BBG000DQQNJ8        NaN
# 69         NaN         NaN        NaN         NaN  BBG000BF6B57        NaN
# 70         NaN         NaN        NaN         NaN  BBG000BRVH05        NaN
#
# ...

# %%
df4=pd.read_html("https://www.basketball-reference.com/players/m/morrima02.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")

# %%
df4
# Out:
# [       Season   Age   Tm   Lg  Pos      G     GS    MP   FG   FGA  ...    FT%  \
#  0     2011-12  22.0  PHO  NBA   PF   63.0    7.0  19.5  2.8   6.9  ...  0.717
#  1     2012-13  23.0  PHO  NBA   PF   82.0   32.0  22.4  3.2   8.0  ...  0.732
#  2     2013-14  24.0  PHO  NBA   PF   81.0    0.0  26.6  5.1  10.4  ...  0.792
#  3     2014-15  25.0  PHO  NBA   PF   82.0   82.0  31.5  6.2  13.4  ...  0.763
#  4     2015-16  26.0  TOT  NBA   PF   64.0   45.0  25.5  4.8  11.2  ...  0.735
#  5     2015-16  26.0  PHO  NBA   PF   37.0   24.0  24.8  4.6  11.6  ...  0.717
#  6     2015-16  26.0  WAS  NBA   PF   27.0   21.0  26.4  5.0  10.6  ...  0.764
#  7     2016-17  27.0  WAS  NBA   PF   76.0   76.0  31.2  5.3  11.7  ...  0.837
#  8     2017-18  28.0  WAS  NBA   PF   73.0   73.0  27.0  4.5   9.4  ...  0.820
#  9     2018-19  29.0  TOT  NBA   PF   58.0   16.0  21.9  3.5   8.3  ...  0.772
#  10    2018-19  29.0  WAS  NBA   PF   34.0   15.0  26.0  4.2   9.6  ...  0.781
# ...

# %%
type(df4)
# Out:
# list

# %%
len(df4)
# Out:
# 6

# %%
df4[0]
# Out:
#        Season   Age   Tm   Lg  Pos      G     GS    MP   FG   FGA  ...    FT%  \
# 0     2011-12  22.0  PHO  NBA   PF   63.0    7.0  19.5  2.8   6.9  ...  0.717
# 1     2012-13  23.0  PHO  NBA   PF   82.0   32.0  22.4  3.2   8.0  ...  0.732
# 2     2013-14  24.0  PHO  NBA   PF   81.0    0.0  26.6  5.1  10.4  ...  0.792
# 3     2014-15  25.0  PHO  NBA   PF   82.0   82.0  31.5  6.2  13.4  ...  0.763
# 4     2015-16  26.0  TOT  NBA   PF   64.0   45.0  25.5  4.8  11.2  ...  0.735
# 5     2015-16  26.0  PHO  NBA   PF   37.0   24.0  24.8  4.6  11.6  ...  0.717
# 6     2015-16  26.0  WAS  NBA   PF   27.0   21.0  26.4  5.0  10.6  ...  0.764
# 7     2016-17  27.0  WAS  NBA   PF   76.0   76.0  31.2  5.3  11.7  ...  0.837
# 8     2017-18  28.0  WAS  NBA   PF   73.0   73.0  27.0  4.5   9.4  ...  0.820
# 9     2018-19  29.0  TOT  NBA   PF   58.0   16.0  21.9  3.5   8.3  ...  0.772
# 10    2018-19  29.0  WAS  NBA   PF   34.0   15.0  26.0  4.2   9.6  ...  0.781
# ...

# %%
df4[0].to_csv("Player_basktball.csv")

# %%
html_data = pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")
for i in range(len(html_data)):
    html_data[i].to_csv(f"html_data{i}.csv", index=False)

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
i="""{
"name":"Itnesh",
"phone_no":34567774647,
"company":["NSIC","MapMyIndia","Indian Railways","MSME","Infosys"]
}"""

# %%
import json

# %%
s1=json.loads(i)

# %%
s1
# Out:
# {'name': 'Itnesh',
#  'phone_no': 34567774647,
#  'company': ['NSIC', 'MapMyIndia', 'Indian Railways', 'MSME', 'Infosys']}

# %%
pd.DataFrame(s1)
# Out:
#      name     phone_no          company
# 0  Itnesh  34567774647             NSIC
# 1  Itnesh  34567774647       MapMyIndia
# 2  Itnesh  34567774647  Indian Railways
# 3  Itnesh  34567774647             MSME
# 4  Itnesh  34567774647          Infosys

# %%
pd.DataFrame(s1, columns=['company'])
# Out:
#            company
# 0             NSIC
# 1       MapMyIndia
# 2  Indian Railways
# 3             MSME
# 4          Infosys

# %% [markdown]
# # fatching the data by api by pandas
# * by the help of request library

# %%
import requests

# %%
requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")
#response 200 means everything ok and i am able to get the data
# Out:
# <Response [200]>

# %%
res=requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
js=res.json()

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41938',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41938/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41938/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41938/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/41938',
#   'id': 918098404,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjY3NTY2MjU4',
#   'number': 41938,
#   'title': 'TYP/BUG: fix CI',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
# ...

# %%
js[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41938',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41938/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41938/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/41938/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/41938',
#  'id': 918098404,
#  'node_id': 'MDExOlB1bGxSZXF1ZXN0NjY3NTY2MjU4',
#  'number': 41938,
#  'title': 'TYP/BUG: fix CI',
#  'user': {'login': 'twoertwein',
#   'id': 6618166,
#   'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/twoertwein',
#   'html_url': 'https://github.com/twoertwein',
#   'followers_url': 'https://api.github.com/users/twoertwein/followers',
# ...

# %%
# we want to fatch the data of title so 
js[0]['title']
# Out:
# 'TYP/BUG: fix CI'

# %%
for i in range(len(js)):
    print(js[i]['title'])
# Out:
# TYP/BUG: fix CI
# CI: intermittent segfaults on `macOS py37_macos` run
# CLN: Remove useless Validation functions
# CI: py 3.10 build failing
# BUG: IntervalIndex.get_indexer with categorical both have nans
# BUG: CategoricalIndex.get_loc(np.nan)
# TST: Add tests for numeric_only default behaviour (GH41351)
# BUG/REF: use sorted_rank_1d for rank_2d
# BUG: pd.Grouper cannot be reused in some cases
# BUG: Timezones are not preserved in Series.mode() output
# DOC: start v1.4.0 release notes
# DOC: fix header level in 1.3 release notes
# PERF: fix regression in reductions for boolean/integer data
# DOC: add contributors to 1.3 release notes
# BUG: Scalar assignment to empty dataframe with loc. Closes GH41891
# REF: de-duplicate Categorical _validate_foo_value
# PERF: cache _should_fallback_to_positional
# REF: give rank1d/2d same nan filling
# REF: de-duplicate _intersection, _difference
# REF: simplify Series.__setitem__
# ENH: Add subset to fillna
# ...

# %%
pd.DataFrame(js, columns=['url','title'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df5=pd.DataFrame(js)

# %%
df5.to_csv('json_dump.csv')

# %%
js[0]['user']
# Out:
# {'login': 'twoertwein',
#  'id': 6618166,
#  'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/twoertwein',
#  'html_url': 'https://github.com/twoertwein',
#  'followers_url': 'https://api.github.com/users/twoertwein/followers',
#  'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#  'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#  'repos_url': 'https://api.github.com/users/twoertwein/repos',
#  'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#  'type': 'User',
# ...

# %%
# list=[]
# for i in range(len(js)):
#         list.append(js[i]['user'])
# pd.DataFrame(list)

# %%
pd.DataFrame(js[i]['user'] for i in range(len(js)))
# Out:
#                  login        id               node_id  \
# 0           twoertwein   6618166  MDQ6VXNlcjY2MTgxNjY=
# 1           mzeitlin11  37011898  MDQ6VXNlcjM3MDExODk4
# 2            lithomas1  47963215  MDQ6VXNlcjQ3OTYzMjE1
# 3         jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 4         jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 5         jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 6      michaelneururer   8530527  MDQ6VXNlcjg1MzA1Mjc=
# 7           mzeitlin11  37011898  MDQ6VXNlcjM3MDExODk4
# 8             mimakaev   9454715  MDQ6VXNlcjk0NTQ3MTU=
# 9        willsthompson   1315884  MDQ6VXNlcjEzMTU4ODQ=
# 10     simonjayhawkins  13159005  MDQ6VXNlcjEzMTU5MDA1
# 11     simonjayhawkins  13159005  MDQ6VXNlcjEzMTU5MDA1
# 12  jorisvandenbossche   1020496  MDQ6VXNlcjEwMjA0OTY=
# 13     simonjayhawkins  13159005  MDQ6VXNlcjEzMTU5MDA1
# 14             klieret  13602468  MDQ6VXNlcjEzNjAyNDY4
# 15        jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# ...

# %%
#reading the json data by pandas lib
json_data=pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
pd.DataFrame.from_records(json_data['user'])
# Out:
#                  login        id               node_id  \
# 0           topper-123  26364415  MDQ6VXNlcjI2MzY0NDE1
# 1         jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 2         jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 3      simonjayhawkins  13159005  MDQ6VXNlcjEzMTU5MDA1
# 4         jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 5            Swanand01  75439077  MDQ6VXNlcjc1NDM5MDc3
# 6      simonjayhawkins  13159005  MDQ6VXNlcjEzMTU5MDA1
# 7              realead  17513912  MDQ6VXNlcjE3NTEzOTEy
# 8              realead  17513912  MDQ6VXNlcjE3NTEzOTEy
# 9             swenlaur  15105451  MDQ6VXNlcjE1MTA1NDUx
# 10  jorisvandenbossche   1020496  MDQ6VXNlcjEwMjA0OTY=
# 11              gcaria  44147817  MDQ6VXNlcjQ0MTQ3ODE3
# 12            attack68  24256554  MDQ6VXNlcjI0MjU2NTU0
# 13     simonjayhawkins  13159005  MDQ6VXNlcjEzMTU5MDA1
# 14           mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 15               huonw   1203825  MDQ6VXNlcjEyMDM4MjU=
# ...

# %%
from_file=pd.read_csv('html_data1.csv')
# to read tne csv file

# %% [markdown]
# # Different type of file formate
# ### 1. to store the data in pickle formate
# * store the data in the form for binary to converting the data into bite code i.e serialised formate
# * _serde_ serrialisation and deserialisation

# %%
from_file.to_pickle('my_pickle')

# %% [markdown]
# # .H5 file , it is another binary file formate

# %%
h5_data= pd.HDFStore('test.h5')

# %%
h5_data['obj1']=from_file
# Out:
# C:\Users\itnes\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['Season', 'Tm', 'Lg', 'Pos'], dtype='object')]
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
h5_data['obj1']
# Out:
#        Season   Age   Tm   Lg  Pos      G     GS    MP   FG   FGA  ...    FT%  \
# 0     2009-10  20.0  OKC  NBA   PF    6.0    0.0  25.5  3.3   5.8  ...  0.700
# 1     2010-11  21.0  OKC  NBA   PF   17.0   17.0  28.8  3.9   8.5  ...  0.825
# 2     2011-12  22.0  OKC  NBA   PF   20.0   20.0  28.5  4.2   8.0  ...  0.722
# 3     2012-13  23.0  OKC  NBA   PF   11.0   11.0  33.3  5.4  12.3  ...  0.792
# 4     2013-14  24.0  OKC  NBA   PF   17.0   17.0  34.2  5.1   8.6  ...  0.765
# 5     2015-16  26.0  OKC  NBA   PF   18.0   18.0  33.4  4.7   9.1  ...  0.750
# 6     2016-17  27.0  TOR  NBA   PF   10.0   10.0  30.7  6.0  13.0  ...  0.846
# 7     2017-18  28.0  TOR  NBA   PF   10.0    9.0  26.0  3.0   7.2  ...  0.818
# 8     2018-19  29.0  TOR  NBA    C   24.0    0.0  20.8  3.8   8.0  ...  0.762
# 9     2019-20  30.0  TOR  NBA    C   11.0    0.0  22.8  5.7  10.0  ...  1.000
# 10    2020-21  31.0  LAC  NBA    C    2.0    0.0   9.0  1.5   3.0  ...  1.000
# ...

# %%
# how to insert the data in h5 file

# %%
h5_data.put('obj2', from_file, format='table')

# %%
#how to fetch the data from table

# %%
h5_data.select('obj2', where=['index >10 and index <14'])
# Out:
#        Season  Age   Tm   Lg  Pos      G     GS    MP   FG  FGA  ...    FT%  \
# 11     Career  NaN  NaN  NBA  NaN  146.0  102.0  28.1  4.5  8.9  ...  0.792
# 12        NaN  NaN  NaN  NaN  NaN    NaN    NaN   NaN  NaN  NaN  ...    NaN
# 13  6 seasons  NaN  OKC  NBA  NaN   89.0   83.0  31.0  4.5  8.8  ...  0.768
#
#     ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 11  1.9  4.7  6.5  0.7  0.4  2.0  1.0  3.1  11.0
# 12  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 13  2.2  4.5  6.7  0.5  0.5  2.5  0.8  3.2  10.9
#
# [3 rows x 30 columns]

# %%
df7=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df7.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df7.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df7.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#select the data with particular data type
df7.dtypes=='object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
#select only object data type
df7.dtypes[df7.dtypes=='object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df7.dtypes[df7.dtypes=='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
# if i want to collect that index which has the object data not any numerical data
df7[df7.dtypes[df7.dtypes=='object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df10=df7[df7.dtypes[df7.dtypes=='object'].index]

# %%
df10.describe()
# Out:
#                       Name   Sex Ticket        Cabin Embarked
# count                  891   891    891          204      889
# unique                 891     2    681          147        3
# top     Nankoff, Mr. Minko  male   1601  C23 C25 C27        S
# freq                     1   577      7            4      644

# %%
# filter the float data type 
df7[df7.dtypes[df7.dtypes=="float64"].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
#fatch the data in name table from 5 to 10 index 
#but in range indexing data always exclude the upper limit of the condition
df7['Name'][5:10]
# Out:
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
df7[['Ticket']][5:16]
# Out:
#        Ticket
# 5      330877
# 6       17463
# 7      349909
# 8      347742
# 9      237736
# 10    PP 9549
# 11     113783
# 12  A/5. 2151
# 13     347082
# 14     350406
# 15     248706

# %%
# If I need the shorted formate
sorted(df7['Ticket'])
# Out:
# ['110152',
#  '110152',
#  '110152',
#  '110413',
#  '110413',
#  '110413',
#  '110465',
#  '110465',
#  '110564',
#  '110813',
#  '111240',
#  '111320',
#  '111361',
#  '111361',
#  '111369',
#  '111426',
#  '111427',
#  '111428',
#  '112050',
#  '112052',
#  '112053',
#  '112058',
#  '112059',
#  '112277',
#  '112379',
#  '113028',
#  '113043',
#  '113050',
#  '113051',
#  '113055',
#  '113056',
#  '113059',
#  '113501',
#  '113503',
#  '113505',
#  '113505',
#  '113509',
#  '113510',
#  '113514',
#  '113572',
#  '113572',
#  '113760',
#  '113760',
#  '113760',
#  '113760',
#  '113767',
#  '113773',
#  '113776',
#  '113776',
#  '113781',
#  '113781',
#  '113781',
#  '113781',
#  '113783',
#  '113784',
#  '113786',
#  '113787',
#  '113788',
#  '113789',
#  '113789',
#  '113792',
#  '113794',
#  '113796',
#  '113798',
#  '113798',
#  '113800',
#  '113803',
#  '113803',
#  '113804',
#  '113806',
#  '113806',
#  '113807',
#  '11668',
#  '11668',
#  '11751',
#  '11751',
#  '11752',
# ...

# %%
df7.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# I can iterate the all columns by one by one 
for i in df7.columns:
    print(df7[i])
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# ...

# %%
    for i in df7.columns:
        print(df7[[i]])
# Out:
#      PassengerId
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ..           ...
# 886          887
# 887          888
# 888          889
# 889          890
# 890          891
#
# [891 rows x 1 columns]
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]
#      Pclass
# 0         3
# 1         1
# 2         3
# 3         1
# 4         3
# ..      ...
# 886       2
# 887       1
# 888       3
# 889       1
# 890       3
#
# [891 rows x 1 columns]
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# ...

# %%
# add the new column with specified data
df7['Itnesh']='Kumar'

# %%
df7
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Import all the data which is already present
df7['Itnehs']=df7['PassengerId']

# %%
df7
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# giving the ouput of data present in cabin columns in the list
pd.Categorical(df7['Cabin'])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
pd.Categorical(df7['Sex'])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
# This is also unique way to extact the of series of particular columns
df7['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
# if we want to extact the data as null value 
df7['Pclass'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Pclass, Length: 891, dtype: bool

# %%
df7['Cabin'].isnull()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
df7['Cabin'][df7['Cabin'].isnull()==True]
# Out:
# 0      NaN
# 2      NaN
# 4      NaN
# 5      NaN
# 7      NaN
#       ...
# 884    NaN
# 885    NaN
# 886    NaN
# 888    NaN
# 890    NaN
# Name: Cabin, Length: 687, dtype: object

# %%
df7['Cabin'][df7['Cabin'].isnull()==False]
# Out:
# 1              C85
# 3             C123
# 6              E46
# 10              G6
# 11            C103
#           ...
# 871            D35
# 872    B51 B53 B55
# 879            C50
# 887            B42
# 889           C148
# Name: Cabin, Length: 204, dtype: object

# %%
ser=df7['Cabin'][df7['Cabin'].isnull()==False]

# %%
ser.index
# Out:
# Int64Index([  1,   3,   6,  10,  11,  21,  23,  27,  31,  52,
#             ...
#             849, 853, 857, 862, 867, 871, 872, 879, 887, 889],
#            dtype='int64', length=204)

# %%
# extract the all not null value data from the data frame
df7.iloc[ser.index]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df7.iloc[[1,3,4,5,6]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch    Ticket     Fare Cabin Embarked  Itnehs Itnesh
# 1      0  PC 17599  71.2833   C85        C       2  Kumar
# 3      0    113803  53.1000  C123        S       4  Kumar
# 4      0    373450   8.0500   NaN        S       5  Kumar
# 5      0    330877   8.4583   NaN        Q       6  Kumar
# ...

# %%
# Fatch the cabin having the null value

# %%
Fatch the cabin having the null value

# %%
seri=df7['Cabin'][df7['Cabin'].isnull()==True]

# %%
seri.index
# Out:
# Int64Index([  0,   2,   4,   5,   7,   8,   9,  12,  13,  14,
#             ...
#             878, 880, 881, 882, 883, 884, 885, 886, 888, 890],
#            dtype='int64', length=687)

# %%
df7.iloc[seri.index]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
#how many cabin has null value ?
len(seri)
# Out:
# 687

# %%
# so lets find the highest paid person name
df7[df7['Fare']==max(df7['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#      Itnehs Itnesh
# 258     259  Kumar
# 679     680  Kumar
# 737     738  Kumar

# %%
df7[df7['Fare']==max(df7['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
# add the new columns and addition of age and passengerID
df7['new_col']=df7['PassengerId']+df7['Age']

# %%
df7
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# task link for total price and name order etc
https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv
