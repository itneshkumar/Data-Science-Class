# %%
import pandas as pd

# %%
data=pd.read_csv('Amazon Web Services.csv')
# Out:
#           user_name                       repo_name   star  \
# 0        serverless                      serverless  39700
# 1        localstack                      localstack  30300
# 2       donnemartin  data-science-ipython-notebooks  21100
# 3       ramitsurana              awesome-kubernetes  11600
# 4               aws                         aws-cli  11000
# 5   kubernetes-sigs                       kubespray  10600
# 6       donnemartin                     awesome-aws   9300
# 7            apereo                             cas   8600
# 8            pulumi                          pulumi   8600
# 9      bregman-arie                devops-exercises   8400
# 10             apex                              up   8200
# 11      aws-amplify                      amplify-js   8100
# 12              aws                         chalice   7900
# 13              aws    serverless-application-model   7900
# 14           google                        go-cloud   7700
# ...
